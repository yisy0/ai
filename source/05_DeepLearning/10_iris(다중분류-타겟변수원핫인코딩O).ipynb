# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:99% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:24pt;}
div.text_cell_render.rendered_html{font-size:20pt;}
div.text_cell_render ul li, code{font-size:22pt; line-height:30px;}
div.output {font-size:24pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:24pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:24pt;padding:5px;}
table.dataframe{font-size:24px;}
</style>
"""))
# Out:
# <style>
# div.container{width:99% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:24pt;}
# div.text_cell_render.rendered_html{font-size:20pt;}
# div.text_cell_render ul li, code{font-size:22pt; line-height:30px;}
# div.output {font-size:24pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:24pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:24pt;padding:5px;}
# table.dataframe{font-size:24px;}
# </style>

# %%
import os # 모델 저장할 폴더가 있는지 여부와 폴더 생성
import numpy as np
import pandas as pd # get_dummies(원핫인코딩), crosstab
import seaborn as sns # iris 데이터(데이터프레임) 가져오기
from sklearn import datasets # iris 데이터(X, y) 가져오기
from sklearn.preprocessing import LabelEncoder # 라벨인코더
from tensorflow.keras.utils import to_categorical # 원핫인코딩 
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, save_model, load_model
from tensorflow.keras.layers import Input, Dense, Dropout, LeakyReLU
from tensorflow.keras import metrics # compile
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt

# %% [markdown]
# - 데이터 셋 생성(seaborn) & 전처리
#     X, y(setosa,versicolor,virginica라벨인코딩-원핫코딩)분리 -> train과 test셋 분리(8:2)
# - 모델 구성(입력4 -> 출력3, layer5: 4->64->128->50->30->3)
# - 모델 학습과정 설정
# - 모델 학습(Earlystopping, ModelCheckpoint추가)
# - 모델평가(시각화, 현재모델과 저장된 최고의 모델 평가, 교차표==혼동행렬)
# - 모델예측/저장

# %% [markdown]
# # 1. 데이터 셋 생성(seaborn) & 전처리

# %%
iris = sns.load_dataset('iris')
iris.loc[::50]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 50            7.0          3.2           4.7          1.4  versicolor
# 100           6.3          3.3           6.0          2.5   virginica

# %%
# 문자변수 원핫인코딩 방법1
encoder = LabelEncoder()
iris['y'] = encoder.fit_transform(iris['species'])
display(iris.loc[::50])
# utils.to_categorical(iris['species'])[:5]
# to_categorical을 하려면 숫자필드로 라벨인코딩먼저
to_categorical(iris['y'])[::50]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  y
# 0             5.1          3.5           1.4          0.2      setosa  0
# 50            7.0          3.2           4.7          1.4  versicolor  1
# 100           6.3          3.3           6.0          2.5   virginica  2
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]], dtype=float32)

# %%
# 문자변수 원핫인코딩 방법2
pd.get_dummies(iris.species)[::50]
# Out:
#      setosa  versicolor  virginica
# 0         1           0          0
# 50        0           1          0
# 100       0           0          1

# %%
# 1. 데이터 생성 및 전처리
iris = sns.load_dataset('iris')
# 독립변수와 종속변수 분리
iris_X = iris.iloc[:, :-1].to_numpy()
iris_y = iris.iloc[:, -1]
iris_Y = pd.get_dummies(iris_y).values
# 훈련셋 : 테스트셋 = 8 : 2
X_train, X_test, Y_train, Y_test = train_test_split(iris_X, iris_Y,
                                                   test_size=0.2,
                                                   stratify=iris_Y, # 층화추출
                                                   random_state=4) 
X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((120, 4), (120, 3), (30, 4), (30, 3))

# %%
# 층화 추출했는지 확인 
pd.Series(np.argmax(Y_train, axis=1)).value_counts()
# Out:
# 0    40
# 1    40
# 2    40
# dtype: int64

# %%
pd.Series(np.argmax(Y_test, axis=1)).value_counts()
# Out:
# 1    10
# 2    10
# 0    10
# dtype: int64

# %% [markdown]
# # 2. 모델 구성
# (입력4 -> 출력3, layer5: 4->64->128->50->30->3)

# %%
model = Sequential()
model.add(Dense(units=64, input_dim=4, activation='relu'))
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=30, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(units=3, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                320
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 50)                6450
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense_3 (Dense)             (None, 30)                1530
#
#  dropout_2 (Dropout)         (None, 30)                0
#
#  dense_4 (Dense)             (None, 3)                 93
#
# =================================================================
# Total params: 16,713
# Trainable params: 16,713
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. 모델 학습과정 설정

# %%
model.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# %% [markdown]
# # 4. 모델 학습
# (Earlystopping, ModelCheckpoint추가)

# %%
model_save_folder = './model/'
import os
if not os.path.exists(model_save_folder): # 폴더 없으면 폴더 생성
    os.mkdir(model_save_folder)
file = model_save_folder \
        + 'iris-{epoch:03d}-loss{val_loss:.4f}-acc{val_accuracy:.4f}.h5'
# 콜백객체
checkpoint = ModelCheckpoint(
                    filepath=file,
                    monitor='val_accuracy', # 모니터링 지표:loss, val_loss, accuracy
                    save_best_only=True,    # 모니터링 지표가 개선된 경우만 저장
                    mode = 'max',
                    verbose=1) # 로그 출력 여부
earlystopping = EarlyStopping(patience=40)# monitor='val_loss' 기본값
hist=model.fit(X_train,Y_train,batch_size=40,
               epochs=200,
               validation_split=0.2,
               callbacks=[checkpoint,earlystopping])
# Out:
# Epoch 1/200
# 1/3 [=========>....................] - ETA: 1s - loss: 1.3322 - accuracy: 0.2750
# Epoch 1: val_accuracy improved from -inf to 0.25000, saving model to ./model\iris-001-loss1.0991-acc0.2500.h5
# 3/3 [==============================] - 1s 130ms/step - loss: 1.2683 - accuracy: 0.3125 - val_loss: 1.0991 - val_accuracy: 0.2500
# Epoch 2/200
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0177 - accuracy: 0.5500
# Epoch 2: val_accuracy did not improve from 0.25000
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0602 - accuracy: 0.5000 - val_loss: 1.0775 - val_accuracy: 0.2500
# Epoch 3/200
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0599 - accuracy: 0.4000
# Epoch 3: val_accuracy did not improve from 0.25000
# 3/3 [==============================] - 0s 16ms/step - loss: 1.0552 - accuracy: 0.4062 - val_loss: 1.0200 - val_accuracy: 0.2500
# Epoch 4/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.9991 - accuracy: 0.5000
# Epoch 4: val_accuracy improved from 0.25000 to 0.58333, saving model to ./model\iris-004-loss0.9274-acc0.5833.h5
# 3/3 [==============================] - 0s 27ms/step - loss: 0.9996 - accuracy: 0.4375 - val_loss: 0.9274 - val_accuracy: 0.5833
# Epoch 5/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.9582 - accuracy: 0.6000
# Epoch 5: val_accuracy did not improve from 0.58333
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9525 - accuracy: 0.6146 - val_loss: 0.8521 - val_accuracy: 0.5833
# Epoch 6/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.8237 - accuracy: 0.6500
# Epoch 6: val_accuracy improved from 0.58333 to 0.70833, saving model to ./model\iris-006-loss0.7819-acc0.7083.h5
# 3/3 [==============================] - 0s 24ms/step - loss: 0.8859 - accuracy: 0.5833 - val_loss: 0.7819 - val_accuracy: 0.7083
# Epoch 7/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.8885 - accuracy: 0.5750
# Epoch 7: val_accuracy improved from 0.70833 to 1.00000, saving model to ./model\iris-007-loss0.7205-acc1.0000.h5
# 3/3 [==============================] - 0s 24ms/step - loss: 0.8770 - accuracy: 0.5729 - val_loss: 0.7205 - val_accuracy: 1.0000
# Epoch 8/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7613 - accuracy: 0.7000
# Epoch 8: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.7884 - accuracy: 0.6562 - val_loss: 0.6679 - val_accuracy: 1.0000
# Epoch 9/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7535 - accuracy: 0.6500
# Epoch 9: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.7225 - accuracy: 0.6667 - val_loss: 0.6173 - val_accuracy: 1.0000
# Epoch 10/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7169 - accuracy: 0.6750
# Epoch 10: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.7007 - accuracy: 0.6771 - val_loss: 0.5525 - val_accuracy: 0.9167
# Epoch 11/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6359 - accuracy: 0.7500
# Epoch 11: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6259 - accuracy: 0.7292 - val_loss: 0.5021 - val_accuracy: 1.0000
# Epoch 12/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6259 - accuracy: 0.7000
# Epoch 12: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6017 - accuracy: 0.7188 - val_loss: 0.4674 - val_accuracy: 1.0000
# Epoch 13/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.5540 - accuracy: 0.7750
# Epoch 13: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5723 - accuracy: 0.7604 - val_loss: 0.4311 - val_accuracy: 1.0000
# Epoch 14/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.5563 - accuracy: 0.6750
# Epoch 14: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5655 - accuracy: 0.7083 - val_loss: 0.3820 - val_accuracy: 1.0000
# Epoch 15/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6044 - accuracy: 0.7750
# Epoch 15: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5278 - accuracy: 0.8021 - val_loss: 0.3509 - val_accuracy: 1.0000
# Epoch 16/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4228 - accuracy: 0.8250
# Epoch 16: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4741 - accuracy: 0.7500 - val_loss: 0.3305 - val_accuracy: 1.0000
# Epoch 17/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4953 - accuracy: 0.7250
# Epoch 17: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4607 - accuracy: 0.7708 - val_loss: 0.3009 - val_accuracy: 1.0000
# Epoch 18/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4029 - accuracy: 0.7500
# Epoch 18: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4164 - accuracy: 0.7812 - val_loss: 0.2631 - val_accuracy: 1.0000
# Epoch 19/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3048 - accuracy: 0.8750
# Epoch 19: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.3635 - accuracy: 0.8438 - val_loss: 0.2535 - val_accuracy: 1.0000
# Epoch 20/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4179 - accuracy: 0.8750
# Epoch 20: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.3983 - accuracy: 0.8438 - val_loss: 0.2320 - val_accuracy: 1.0000
# Epoch 21/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3420 - accuracy: 0.9000
# Epoch 21: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3753 - accuracy: 0.8542 - val_loss: 0.2325 - val_accuracy: 0.9583
# Epoch 22/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3774 - accuracy: 0.8500
# Epoch 22: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.3574 - accuracy: 0.8438 - val_loss: 0.2066 - val_accuracy: 1.0000
# Epoch 23/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4202 - accuracy: 0.7750
# Epoch 23: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3459 - accuracy: 0.8125 - val_loss: 0.1687 - val_accuracy: 1.0000
# Epoch 24/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3719 - accuracy: 0.8000
# Epoch 24: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2859 - accuracy: 0.8750 - val_loss: 0.1608 - val_accuracy: 1.0000
# Epoch 25/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2673 - accuracy: 0.9250
# Epoch 25: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2598 - accuracy: 0.9375 - val_loss: 0.1392 - val_accuracy: 1.0000
# Epoch 26/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3488 - accuracy: 0.8500
# Epoch 26: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3645 - accuracy: 0.8438 - val_loss: 0.1292 - val_accuracy: 1.0000
# Epoch 27/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3481 - accuracy: 0.8750
# Epoch 27: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2919 - accuracy: 0.8750 - val_loss: 0.1412 - val_accuracy: 0.9583
# Epoch 28/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1726 - accuracy: 0.9500
# Epoch 28: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2369 - accuracy: 0.9167 - val_loss: 0.1225 - val_accuracy: 0.9583
# Epoch 29/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1685 - accuracy: 0.9500
# Epoch 29: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2351 - accuracy: 0.8958 - val_loss: 0.1080 - val_accuracy: 1.0000
# Epoch 30/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2848 - accuracy: 0.8750
# Epoch 30: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2524 - accuracy: 0.8854 - val_loss: 0.0766 - val_accuracy: 1.0000
# Epoch 31/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1532 - accuracy: 0.9750
# Epoch 31: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1952 - accuracy: 0.9271 - val_loss: 0.0719 - val_accuracy: 1.0000
# Epoch 32/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2958 - accuracy: 0.8750
# Epoch 32: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2642 - accuracy: 0.8750 - val_loss: 0.0708 - val_accuracy: 1.0000
# Epoch 33/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1540 - accuracy: 0.9250
# Epoch 33: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1807 - accuracy: 0.9062 - val_loss: 0.0680 - val_accuracy: 1.0000
# Epoch 34/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1807 - accuracy: 1.0000
# Epoch 34: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2395 - accuracy: 0.9271 - val_loss: 0.0618 - val_accuracy: 1.0000
# Epoch 35/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2076 - accuracy: 0.9000
# Epoch 35: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1738 - accuracy: 0.9479 - val_loss: 0.0690 - val_accuracy: 1.0000
# Epoch 36/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0997 - accuracy: 0.9750
# Epoch 36: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1681 - accuracy: 0.9375 - val_loss: 0.0468 - val_accuracy: 1.0000
# Epoch 37/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1148 - accuracy: 0.9750
# Epoch 37: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2312 - accuracy: 0.8750 - val_loss: 0.0432 - val_accuracy: 1.0000
# Epoch 38/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1590 - accuracy: 0.9000
# Epoch 38: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1850 - accuracy: 0.9271 - val_loss: 0.1201 - val_accuracy: 0.9583
# Epoch 39/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1430 - accuracy: 0.9500
# Epoch 39: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2334 - accuracy: 0.8958 - val_loss: 0.1234 - val_accuracy: 0.9583
# Epoch 40/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1146 - accuracy: 0.9500
# Epoch 40: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1866 - accuracy: 0.9167 - val_loss: 0.0360 - val_accuracy: 1.0000
# Epoch 41/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2070 - accuracy: 0.9500
# Epoch 41: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1267 - accuracy: 0.9688 - val_loss: 0.0351 - val_accuracy: 1.0000
# Epoch 42/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2849 - accuracy: 0.8750
# Epoch 42: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1909 - accuracy: 0.9271 - val_loss: 0.0446 - val_accuracy: 1.0000
# Epoch 43/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2082 - accuracy: 0.9000
# Epoch 43: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1728 - accuracy: 0.9271 - val_loss: 0.0460 - val_accuracy: 1.0000
# Epoch 44/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0867 - accuracy: 1.0000
# Epoch 44: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1258 - accuracy: 0.9688 - val_loss: 0.0445 - val_accuracy: 1.0000
# Epoch 45/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1668 - accuracy: 0.9500
# Epoch 45: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1503 - accuracy: 0.9583 - val_loss: 0.0310 - val_accuracy: 1.0000
# Epoch 46/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1411 - accuracy: 0.9500
# Epoch 46: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1654 - accuracy: 0.9479 - val_loss: 0.0271 - val_accuracy: 1.0000
# Epoch 47/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0803 - accuracy: 1.0000
# Epoch 47: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1484 - accuracy: 0.9688 - val_loss: 0.0378 - val_accuracy: 1.0000
# Epoch 48/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0934 - accuracy: 0.9750
# Epoch 48: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1123 - accuracy: 0.9583 - val_loss: 0.0742 - val_accuracy: 0.9583
# Epoch 49/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1979 - accuracy: 0.9250
# Epoch 49: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1278 - accuracy: 0.9583 - val_loss: 0.0537 - val_accuracy: 0.9583
# Epoch 50/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1470 - accuracy: 0.9500
# Epoch 50: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1381 - accuracy: 0.9375 - val_loss: 0.0229 - val_accuracy: 1.0000
# Epoch 51/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1169 - accuracy: 0.9750
# Epoch 51: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1265 - accuracy: 0.9583 - val_loss: 0.0224 - val_accuracy: 1.0000
# Epoch 52/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1959 - accuracy: 0.9000
# Epoch 52: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1609 - accuracy: 0.9479 - val_loss: 0.0263 - val_accuracy: 1.0000
# Epoch 53/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1596 - accuracy: 0.9250
# Epoch 53: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1573 - accuracy: 0.9375 - val_loss: 0.0426 - val_accuracy: 1.0000
# Epoch 54/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1277 - accuracy: 0.9500
# Epoch 54: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1375 - accuracy: 0.9479 - val_loss: 0.0211 - val_accuracy: 1.0000
# Epoch 55/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2411 - accuracy: 0.8750
# Epoch 55: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.2010 - accuracy: 0.9062 - val_loss: 0.0203 - val_accuracy: 1.0000
# Epoch 56/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1120 - accuracy: 0.9250
# Epoch 56: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1673 - accuracy: 0.9271 - val_loss: 0.0261 - val_accuracy: 1.0000
# Epoch 57/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1423 - accuracy: 0.9250
# Epoch 57: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1056 - accuracy: 0.9375 - val_loss: 0.0750 - val_accuracy: 0.9583
# Epoch 58/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2551 - accuracy: 0.8500
# Epoch 58: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1769 - accuracy: 0.9167 - val_loss: 0.0379 - val_accuracy: 1.0000
# Epoch 59/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2126 - accuracy: 0.9250
# Epoch 59: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1491 - accuracy: 0.9479 - val_loss: 0.0253 - val_accuracy: 1.0000
# Epoch 60/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0435 - accuracy: 1.0000
# Epoch 60: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1391 - accuracy: 0.9375 - val_loss: 0.0235 - val_accuracy: 1.0000
# Epoch 61/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2641 - accuracy: 0.9250
# Epoch 61: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1601 - accuracy: 0.9375 - val_loss: 0.0279 - val_accuracy: 1.0000
# Epoch 62/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0269 - accuracy: 1.0000
# Epoch 62: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0988 - accuracy: 0.9792 - val_loss: 0.0348 - val_accuracy: 1.0000
# Epoch 63/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0991 - accuracy: 0.9750
# Epoch 63: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1232 - accuracy: 0.9688 - val_loss: 0.0294 - val_accuracy: 1.0000
# Epoch 64/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2015 - accuracy: 0.9500
# Epoch 64: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1196 - accuracy: 0.9792 - val_loss: 0.0263 - val_accuracy: 1.0000
# Epoch 65/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0684 - accuracy: 0.9750
# Epoch 65: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1100 - accuracy: 0.9583 - val_loss: 0.0266 - val_accuracy: 1.0000
# Epoch 66/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0822 - accuracy: 0.9750
# Epoch 66: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1337 - accuracy: 0.9688 - val_loss: 0.0291 - val_accuracy: 1.0000
# Epoch 67/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1401 - accuracy: 0.8750
# Epoch 67: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1412 - accuracy: 0.9271 - val_loss: 0.0170 - val_accuracy: 1.0000
# Epoch 68/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1231 - accuracy: 0.9500
# Epoch 68: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1109 - accuracy: 0.9688 - val_loss: 0.0166 - val_accuracy: 1.0000
# Epoch 69/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0874 - accuracy: 0.9500
# Epoch 69: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1411 - accuracy: 0.9688 - val_loss: 0.0195 - val_accuracy: 1.0000
# Epoch 70/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0574 - accuracy: 0.9750
# Epoch 70: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1315 - accuracy: 0.9479 - val_loss: 0.0226 - val_accuracy: 1.0000
# Epoch 71/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1030 - accuracy: 0.9250
# Epoch 71: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1567 - accuracy: 0.9375 - val_loss: 0.0287 - val_accuracy: 1.0000
# Epoch 72/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1183 - accuracy: 0.9500
# Epoch 72: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1057 - accuracy: 0.9479 - val_loss: 0.0274 - val_accuracy: 1.0000
# Epoch 73/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0501 - accuracy: 1.0000
# Epoch 73: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0842 - accuracy: 0.9896 - val_loss: 0.0342 - val_accuracy: 1.0000
# Epoch 74/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1003 - accuracy: 0.9250
# Epoch 74: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1277 - accuracy: 0.9479 - val_loss: 0.0349 - val_accuracy: 1.0000
# Epoch 75/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0748 - accuracy: 0.9750
# Epoch 75: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0812 - accuracy: 0.9792 - val_loss: 0.0255 - val_accuracy: 1.0000
# Epoch 76/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1224 - accuracy: 0.9250
# Epoch 76: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1126 - accuracy: 0.9583 - val_loss: 0.0296 - val_accuracy: 1.0000
# Epoch 77/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0951 - accuracy: 0.9750
# Epoch 77: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0776 - accuracy: 0.9896 - val_loss: 0.0281 - val_accuracy: 1.0000
# Epoch 78/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1054 - accuracy: 0.9500
# Epoch 78: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1029 - accuracy: 0.9688 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 79/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1177 - accuracy: 0.9750
# Epoch 79: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1418 - accuracy: 0.9583 - val_loss: 0.0189 - val_accuracy: 1.0000
# Epoch 80/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1485 - accuracy: 0.9500
# Epoch 80: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1065 - accuracy: 0.9583 - val_loss: 0.0531 - val_accuracy: 0.9583
# Epoch 81/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0871 - accuracy: 0.9750
# Epoch 81: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1192 - accuracy: 0.9479 - val_loss: 0.0410 - val_accuracy: 1.0000
# Epoch 82/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1606 - accuracy: 0.9500
# Epoch 82: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1417 - accuracy: 0.9583 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 83/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1049 - accuracy: 0.9750
# Epoch 83: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1175 - accuracy: 0.9688 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 84/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0501 - accuracy: 1.0000
# Epoch 84: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0797 - accuracy: 0.9792 - val_loss: 0.0266 - val_accuracy: 1.0000
# Epoch 85/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0920 - accuracy: 0.9750
# Epoch 85: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0976 - accuracy: 0.9688 - val_loss: 0.0595 - val_accuracy: 0.9583
# Epoch 86/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1846 - accuracy: 0.9000
# Epoch 86: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1179 - accuracy: 0.9375 - val_loss: 0.0395 - val_accuracy: 1.0000
# Epoch 87/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0650 - accuracy: 0.9750
# Epoch 87: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0734 - accuracy: 0.9792 - val_loss: 0.0236 - val_accuracy: 1.0000
# Epoch 88/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0708 - accuracy: 0.9750
# Epoch 88: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0717 - accuracy: 0.9792 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 89/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1598 - accuracy: 0.9500
# Epoch 89: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1007 - accuracy: 0.9688 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 90/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0430 - accuracy: 1.0000
# Epoch 90: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0699 - accuracy: 0.9896 - val_loss: 0.0192 - val_accuracy: 1.0000
# Epoch 91/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0416 - accuracy: 1.0000
# Epoch 91: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0810 - accuracy: 0.9792 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 92/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1539 - accuracy: 0.9750
# Epoch 92: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1111 - accuracy: 0.9792 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 93/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1612 - accuracy: 0.9250
# Epoch 93: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0809 - accuracy: 0.9688 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 94/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2118 - accuracy: 0.9250
# Epoch 94: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1204 - accuracy: 0.9688 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 95/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0205 - accuracy: 1.0000
# Epoch 95: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0883 - accuracy: 0.9792 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 96/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0181 - accuracy: 1.0000
# Epoch 96: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0899 - accuracy: 0.9896 - val_loss: 0.0282 - val_accuracy: 1.0000
# Epoch 97/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0354 - accuracy: 1.0000
# Epoch 97: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0625 - accuracy: 0.9792 - val_loss: 0.0311 - val_accuracy: 1.0000
# Epoch 98/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0604 - accuracy: 0.9750
# Epoch 98: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0763 - accuracy: 0.9688 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 99/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1992 - accuracy: 0.9000
# Epoch 99: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1018 - accuracy: 0.9583 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 100/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1382 - accuracy: 0.9750
# Epoch 100: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0789 - accuracy: 0.9896 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 101/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0467 - accuracy: 1.0000
# Epoch 101: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0782 - accuracy: 0.9896 - val_loss: 0.0284 - val_accuracy: 1.0000
# Epoch 102/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0128 - accuracy: 1.0000
# Epoch 102: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0824 - accuracy: 0.9479 - val_loss: 0.0393 - val_accuracy: 0.9583
# Epoch 103/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1086 - accuracy: 0.9500
# Epoch 103: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0770 - accuracy: 0.9688 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 104/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0525 - accuracy: 0.9750
# Epoch 104: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0940 - accuracy: 0.9583 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 105/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1114 - accuracy: 0.9500
# Epoch 105: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1206 - accuracy: 0.9375 - val_loss: 0.0124 - val_accuracy: 1.0000
# Epoch 106/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0744 - accuracy: 0.9750
# Epoch 106: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0859 - accuracy: 0.9792 - val_loss: 0.0638 - val_accuracy: 0.9583
# Epoch 107/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1566 - accuracy: 0.9250
# Epoch 107: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.1228 - accuracy: 0.9375 - val_loss: 0.0303 - val_accuracy: 1.0000
# Epoch 108/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0524 - accuracy: 0.9750
# Epoch 108: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0731 - accuracy: 0.9688 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 109/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1160 - accuracy: 0.9500
# Epoch 109: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1187 - accuracy: 0.9583 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 110/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0645 - accuracy: 0.9750
# Epoch 110: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0724 - accuracy: 0.9792 - val_loss: 0.0291 - val_accuracy: 1.0000
# Epoch 111/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0414 - accuracy: 1.0000
# Epoch 111: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0902 - accuracy: 0.9792 - val_loss: 0.0419 - val_accuracy: 0.9583
# Epoch 112/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0692 - accuracy: 0.9750
# Epoch 112: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0869 - accuracy: 0.9792 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 113/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0379 - accuracy: 1.0000
# Epoch 113: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0821 - accuracy: 0.9896 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 114/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1195 - accuracy: 0.9500
# Epoch 114: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0848 - accuracy: 0.9688 - val_loss: 0.0217 - val_accuracy: 1.0000
# Epoch 115/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0441 - accuracy: 0.9750
# Epoch 115: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1023 - accuracy: 0.9688 - val_loss: 0.0618 - val_accuracy: 0.9583
# Epoch 116/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0239 - accuracy: 1.0000
# Epoch 116: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0796 - accuracy: 0.9688 - val_loss: 0.0508 - val_accuracy: 0.9583
# Epoch 117/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0461 - accuracy: 1.0000
# Epoch 117: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0831 - accuracy: 0.9688 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 118/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0511 - accuracy: 0.9750
# Epoch 118: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0736 - accuracy: 0.9792 - val_loss: 0.0107 - val_accuracy: 1.0000
# Epoch 119/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2452 - accuracy: 0.9500
# Epoch 119: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1303 - accuracy: 0.9688 - val_loss: 0.0285 - val_accuracy: 1.0000
# Epoch 120/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0832 - accuracy: 0.9750
# Epoch 120: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0865 - accuracy: 0.9792 - val_loss: 0.0576 - val_accuracy: 0.9583
# Epoch 121/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0315 - accuracy: 1.0000
# Epoch 121: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0834 - accuracy: 0.9688 - val_loss: 0.0252 - val_accuracy: 1.0000
# Epoch 122/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0216 - accuracy: 1.0000
# Epoch 122: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0601 - accuracy: 0.9896 - val_loss: 0.0105 - val_accuracy: 1.0000
# Epoch 123/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0667 - accuracy: 0.9750
# Epoch 123: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0733 - accuracy: 0.9792 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 124/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1440 - accuracy: 0.9500
# Epoch 124: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0990 - accuracy: 0.9792 - val_loss: 0.0217 - val_accuracy: 1.0000
# Epoch 125/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0381 - accuracy: 1.0000
# Epoch 125: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0744 - accuracy: 0.9792 - val_loss: 0.0334 - val_accuracy: 1.0000
# Epoch 126/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1867 - accuracy: 0.8750
# Epoch 126: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1045 - accuracy: 0.9375 - val_loss: 0.0155 - val_accuracy: 1.0000
# Epoch 127/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0563 - accuracy: 0.9750
# Epoch 127: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 12ms/step - loss: 0.1195 - accuracy: 0.9688 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 128/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0777 - accuracy: 0.9750
# Epoch 128: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0854 - accuracy: 0.9792 - val_loss: 0.0194 - val_accuracy: 1.0000
# Epoch 129/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0667 - accuracy: 0.9750
# Epoch 129: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0540 - accuracy: 0.9896 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 130/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0647 - accuracy: 0.9750
# Epoch 130: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0946 - accuracy: 0.9792 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 131/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2138 - accuracy: 0.9500
# Epoch 131: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1045 - accuracy: 0.9792 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 132/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0379 - accuracy: 0.9750
# Epoch 132: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0691 - accuracy: 0.9688 - val_loss: 0.0217 - val_accuracy: 1.0000
# Epoch 133/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1190 - accuracy: 0.9500
# Epoch 133: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0645 - accuracy: 0.9792 - val_loss: 0.0208 - val_accuracy: 1.0000
# Epoch 134/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0284 - accuracy: 1.0000
# Epoch 134: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0472 - accuracy: 0.9896 - val_loss: 0.0208 - val_accuracy: 1.0000
# Epoch 135/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1268 - accuracy: 0.9750
# Epoch 135: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0656 - accuracy: 0.9896 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 136/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1075 - accuracy: 0.9750
# Epoch 136: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0656 - accuracy: 0.9896 - val_loss: 0.0229 - val_accuracy: 1.0000
# Epoch 137/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0791 - accuracy: 1.0000
# Epoch 137: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0796 - accuracy: 0.9896 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 138/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1128 - accuracy: 0.9750
# Epoch 138: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0683 - accuracy: 0.9896 - val_loss: 0.0102 - val_accuracy: 1.0000
# Epoch 139/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1021 - accuracy: 0.9750
# Epoch 139: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0636 - accuracy: 0.9896 - val_loss: 0.0147 - val_accuracy: 1.0000
# Epoch 140/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0409 - accuracy: 1.0000
# Epoch 140: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0861 - accuracy: 0.9688 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 141/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1404 - accuracy: 0.9750
# Epoch 141: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0760 - accuracy: 0.9896 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 142/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0193 - accuracy: 1.0000
# Epoch 142: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0538 - accuracy: 0.9896 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch 143/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0400 - accuracy: 0.9750
# Epoch 143: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0580 - accuracy: 0.9792 - val_loss: 0.0256 - val_accuracy: 1.0000
# Epoch 144/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0281 - accuracy: 1.0000
# Epoch 144: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0888 - accuracy: 0.9792 - val_loss: 0.0193 - val_accuracy: 1.0000

# %% [markdown]
# # 5. 모델 평가
# (시각화, 현재모델과 저장된 최고의 모델 평가, 교차표==혼동행렬)

# %%
# 학습과정 표시하기
import matplotlib.pyplot as plt
fig, loss_ax = plt.subplots(figsize=(10,6))
loss_ax.plot(hist.history['loss'], 'y', label='train_loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val_loss')
acc_ax = loss_ax.twinx() # loss_ax와 x축을 공유하는 acc_ax 생성
acc_ax.plot(hist.history['accuracy'], 'g', label='train_accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'b', label='val_accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')
loss_ax.legend(bbox_to_anchor=(0.955, 0.7))
acc_ax.legend(loc='center right')
plt.show()

# %%
# 모델 평가
loss_and_acc =model.evaluate(X_test, Y_test, verbose=0)
print(f'loss:{loss_and_acc[0]:.4f}, accuracy:{loss_and_acc[1]:.4f}')
# Out:
# loss:0.1553, accuracy:0.9333

# %%
model1 = load_model('model/iris-007-loss0.7205-acc1.0000.h5')
loss_and_acc1 =model1.evaluate(X_test, Y_test, verbose=0)
print(f'loss:{loss_and_acc1[0]:.4f}, accuracy:{loss_and_acc1[1]:.4f}')
# Out:
# loss:0.7289, accuracy:1.0000

# %%
model2 = load_model('model/iris-005-loss0.7852-acc1.0000.h5')
loss_and_acc2 =model2.evaluate(X_test, Y_test, verbose=0)
print(f'loss:{loss_and_acc2[0]:.4f}, accuracy:{loss_and_acc2[1]:.4f}')
# Out:
# loss:0.7916, accuracy:0.9333
