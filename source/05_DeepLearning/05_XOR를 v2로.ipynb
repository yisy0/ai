# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:99% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:24pt;}
div.text_cell_render.rendered_html{font-size:20pt;}
div.text_cell_render ul li{font-size:22pt; line-height:30px;}
div.output {font-size:24pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:24pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:24pt;padding:5px;}
table.dataframe{font-size:24px;}
</style>
"""))
# Out:
# <style>
# div.container{width:99% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:24pt;}
# div.text_cell_render.rendered_html{font-size:20pt;}
# div.text_cell_render ul li{font-size:22pt; line-height:30px;}
# div.output {font-size:24pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:24pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:24pt;padding:5px;}
# table.dataframe{font-size:24px;}
# </style>

# %%
import numpy as np
from tensorflow.keras.models import Sequential # 모델 객체 생성
from tensorflow.keras.layers import Input, Dense # 모델 layer 쌓을 때 필요
import matplotlib.pyplot as plt

# %%
# 1. data set
x_data = np.array([[0, 0],
                   [0, 1],
                   [1, 0], 
                   [1, 1]])
y_data = np.array([[0], [1], [1], [0]])
# 2. 모델구성
model = Sequential()
# model.add(Input(shape=2))
model.add(Dense(units=10, # 출력 갯수
               input_dim=2, # input_shape = (2,) # 입력 갯수
               activation='relu')) # 활성화 함수
model.add(Dense(units=20, activation='relu')) # 은닉층에서는 input_shape는 X
model.add(Dense(10, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
print(model.summary())
# 3. 모델 학습과정 설정
    # loss : mae(회귀분석), binary_crossentropy(이진분류=로지스틱회귀분석), 
            # categorical_crossentropy(다중분류-원핫인코딩을 한 경우)
            # sparse_categorical_crossentropy(다중분류-원핫인코딩을 안 한 경우)
model.compile(loss = 'binary_crossentropy',  # 손실함수(loss function)
             optimizer= 'adam',
             metrics=['binary_accuracy']) # 2진분류
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 10)                30
#
#  dense_9 (Dense)             (None, 20)                220
#
#  dense_10 (Dense)            (None, 10)                210
#
#  dense_11 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 471
# Trainable params: 471
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# 4. 학습
hist = model.fit(x_data, y_data, epochs=300, #batch_size=2, 
                 verbose=2)
# Out:
# Epoch 1/300
# 1/1 - 0s - loss: 0.6970 - binary_accuracy: 0.5000 - 428ms/epoch - 428ms/step
# Epoch 2/300
# 1/1 - 0s - loss: 0.6961 - binary_accuracy: 0.2500 - 2ms/epoch - 2ms/step
# Epoch 3/300
# 1/1 - 0s - loss: 0.6950 - binary_accuracy: 0.2500 - 3ms/epoch - 3ms/step
# Epoch 4/300
# 1/1 - 0s - loss: 0.6939 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 5/300
# 1/1 - 0s - loss: 0.6930 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 6/300
# 1/1 - 0s - loss: 0.6920 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 7/300
# 1/1 - 0s - loss: 0.6910 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 8/300
# 1/1 - 0s - loss: 0.6899 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 9/300
# 1/1 - 0s - loss: 0.6888 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 10/300
# 1/1 - 0s - loss: 0.6878 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 11/300
# 1/1 - 0s - loss: 0.6869 - binary_accuracy: 0.5000 - 6ms/epoch - 6ms/step
# Epoch 12/300
# 1/1 - 0s - loss: 0.6861 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 13/300
# 1/1 - 0s - loss: 0.6853 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 14/300
# 1/1 - 0s - loss: 0.6845 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 15/300
# 1/1 - 0s - loss: 0.6836 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 16/300
# 1/1 - 0s - loss: 0.6826 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 17/300
# 1/1 - 0s - loss: 0.6815 - binary_accuracy: 0.5000 - 7ms/epoch - 7ms/step
# Epoch 18/300
# 1/1 - 0s - loss: 0.6802 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 19/300
# 1/1 - 0s - loss: 0.6788 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 20/300
# 1/1 - 0s - loss: 0.6774 - binary_accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 21/300
# 1/1 - 0s - loss: 0.6760 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 22/300
# 1/1 - 0s - loss: 0.6748 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 23/300
# 1/1 - 0s - loss: 0.6738 - binary_accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 24/300
# 1/1 - 0s - loss: 0.6727 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 25/300
# 1/1 - 0s - loss: 0.6715 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 26/300
# 1/1 - 0s - loss: 0.6702 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 27/300
# 1/1 - 0s - loss: 0.6689 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 28/300
# 1/1 - 0s - loss: 0.6676 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 29/300
# 1/1 - 0s - loss: 0.6661 - binary_accuracy: 0.7500 - 6ms/epoch - 6ms/step
# Epoch 30/300
# 1/1 - 0s - loss: 0.6649 - binary_accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 31/300
# 1/1 - 0s - loss: 0.6637 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 32/300
# 1/1 - 0s - loss: 0.6626 - binary_accuracy: 0.7500 - 3ms/epoch - 3ms/step
# Epoch 33/300
# 1/1 - 0s - loss: 0.6614 - binary_accuracy: 0.7500 - 2ms/epoch - 2ms/step
# Epoch 34/300
# 1/1 - 0s - loss: 0.6600 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 35/300
# 1/1 - 0s - loss: 0.6585 - binary_accuracy: 1.0000 - 9ms/epoch - 9ms/step
# Epoch 36/300
# 1/1 - 0s - loss: 0.6570 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 37/300
# 1/1 - 0s - loss: 0.6556 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 38/300
# 1/1 - 0s - loss: 0.6542 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 39/300
# 1/1 - 0s - loss: 0.6528 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 40/300
# 1/1 - 0s - loss: 0.6516 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 41/300
# 1/1 - 0s - loss: 0.6504 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 42/300
# 1/1 - 0s - loss: 0.6491 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 43/300
# 1/1 - 0s - loss: 0.6478 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 44/300
# 1/1 - 0s - loss: 0.6465 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 45/300
# 1/1 - 0s - loss: 0.6451 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 46/300
# 1/1 - 0s - loss: 0.6437 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 47/300
# 1/1 - 0s - loss: 0.6424 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 48/300
# 1/1 - 0s - loss: 0.6409 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 49/300
# 1/1 - 0s - loss: 0.6393 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 50/300
# 1/1 - 0s - loss: 0.6379 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 51/300
# 1/1 - 0s - loss: 0.6365 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 52/300
# 1/1 - 0s - loss: 0.6350 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 53/300
# 1/1 - 0s - loss: 0.6336 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 54/300
# 1/1 - 0s - loss: 0.6321 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 55/300
# 1/1 - 0s - loss: 0.6305 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 56/300
# 1/1 - 0s - loss: 0.6288 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 57/300
# 1/1 - 0s - loss: 0.6271 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 58/300
# 1/1 - 0s - loss: 0.6255 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 59/300
# 1/1 - 0s - loss: 0.6239 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 60/300
# 1/1 - 0s - loss: 0.6222 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 61/300
# 1/1 - 0s - loss: 0.6204 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 62/300
# 1/1 - 0s - loss: 0.6188 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 63/300
# 1/1 - 0s - loss: 0.6173 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 64/300
# 1/1 - 0s - loss: 0.6155 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 65/300
# 1/1 - 0s - loss: 0.6139 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 66/300
# 1/1 - 0s - loss: 0.6123 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 67/300
# 1/1 - 0s - loss: 0.6106 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 68/300
# 1/1 - 0s - loss: 0.6088 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 69/300
# 1/1 - 0s - loss: 0.6070 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 70/300
# 1/1 - 0s - loss: 0.6052 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 71/300
# 1/1 - 0s - loss: 0.6034 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 72/300
# 1/1 - 0s - loss: 0.6016 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 73/300
# 1/1 - 0s - loss: 0.5999 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 74/300
# 1/1 - 0s - loss: 0.5982 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 75/300
# 1/1 - 0s - loss: 0.5963 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 76/300
# 1/1 - 0s - loss: 0.5945 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 77/300
# 1/1 - 0s - loss: 0.5925 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 78/300
# 1/1 - 0s - loss: 0.5907 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 79/300
# 1/1 - 0s - loss: 0.5888 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 80/300
# 1/1 - 0s - loss: 0.5870 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 81/300
# 1/1 - 0s - loss: 0.5849 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 82/300
# 1/1 - 0s - loss: 0.5829 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 83/300
# 1/1 - 0s - loss: 0.5810 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 84/300
# 1/1 - 0s - loss: 0.5790 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 85/300
# 1/1 - 0s - loss: 0.5769 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 86/300
# 1/1 - 0s - loss: 0.5748 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 87/300
# 1/1 - 0s - loss: 0.5728 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 88/300
# 1/1 - 0s - loss: 0.5707 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 89/300
# 1/1 - 0s - loss: 0.5687 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 90/300
# 1/1 - 0s - loss: 0.5666 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 91/300
# 1/1 - 0s - loss: 0.5644 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 92/300
# 1/1 - 0s - loss: 0.5622 - binary_accuracy: 1.0000 - 998us/epoch - 998us/step
# Epoch 93/300
# 1/1 - 0s - loss: 0.5602 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 94/300
# 1/1 - 0s - loss: 0.5580 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 95/300
# 1/1 - 0s - loss: 0.5557 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 96/300
# 1/1 - 0s - loss: 0.5536 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 97/300
# 1/1 - 0s - loss: 0.5514 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 98/300
# 1/1 - 0s - loss: 0.5490 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 99/300
# 1/1 - 0s - loss: 0.5468 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 100/300
# 1/1 - 0s - loss: 0.5446 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 101/300
# 1/1 - 0s - loss: 0.5424 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 102/300
# 1/1 - 0s - loss: 0.5400 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 103/300
# 1/1 - 0s - loss: 0.5378 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 104/300
# 1/1 - 0s - loss: 0.5356 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 105/300
# 1/1 - 0s - loss: 0.5333 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 106/300
# 1/1 - 0s - loss: 0.5308 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 107/300
# 1/1 - 0s - loss: 0.5286 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 108/300
# 1/1 - 0s - loss: 0.5262 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 109/300
# 1/1 - 0s - loss: 0.5238 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 110/300
# 1/1 - 0s - loss: 0.5214 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 111/300
# 1/1 - 0s - loss: 0.5190 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 112/300
# 1/1 - 0s - loss: 0.5166 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 113/300
# 1/1 - 0s - loss: 0.5141 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 114/300
# 1/1 - 0s - loss: 0.5116 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 115/300
# 1/1 - 0s - loss: 0.5091 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 116/300
# 1/1 - 0s - loss: 0.5066 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 117/300
# 1/1 - 0s - loss: 0.5043 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 118/300
# 1/1 - 0s - loss: 0.5018 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 119/300
# 1/1 - 0s - loss: 0.4993 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 120/300
# 1/1 - 0s - loss: 0.4968 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 121/300
# 1/1 - 0s - loss: 0.4943 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 122/300
# 1/1 - 0s - loss: 0.4918 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 123/300
# 1/1 - 0s - loss: 0.4893 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 124/300
# 1/1 - 0s - loss: 0.4867 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 125/300
# 1/1 - 0s - loss: 0.4841 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 126/300
# 1/1 - 0s - loss: 0.4815 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 127/300
# 1/1 - 0s - loss: 0.4790 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 128/300
# 1/1 - 0s - loss: 0.4764 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 129/300
# 1/1 - 0s - loss: 0.4739 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 130/300
# 1/1 - 0s - loss: 0.4714 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 131/300
# 1/1 - 0s - loss: 0.4688 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 132/300
# 1/1 - 0s - loss: 0.4662 - binary_accuracy: 1.0000 - 13ms/epoch - 13ms/step
# Epoch 133/300
# 1/1 - 0s - loss: 0.4636 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 134/300
# 1/1 - 0s - loss: 0.4610 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 135/300
# 1/1 - 0s - loss: 0.4585 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 136/300
# 1/1 - 0s - loss: 0.4561 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 137/300
# 1/1 - 0s - loss: 0.4535 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 138/300
# 1/1 - 0s - loss: 0.4511 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 139/300
# 1/1 - 0s - loss: 0.4485 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 140/300
# 1/1 - 0s - loss: 0.4459 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 141/300
# 1/1 - 0s - loss: 0.4435 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 142/300
# 1/1 - 0s - loss: 0.4410 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 143/300
# 1/1 - 0s - loss: 0.4385 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 144/300
# 1/1 - 0s - loss: 0.4359 - binary_accuracy: 1.0000 - 998us/epoch - 998us/step
# Epoch 145/300
# 1/1 - 0s - loss: 0.4335 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 146/300
# 1/1 - 0s - loss: 0.4310 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 147/300
# 1/1 - 0s - loss: 0.4285 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 148/300
# 1/1 - 0s - loss: 0.4260 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 149/300
# 1/1 - 0s - loss: 0.4236 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 150/300
# 1/1 - 0s - loss: 0.4211 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 151/300
# 1/1 - 0s - loss: 0.4186 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 152/300
# 1/1 - 0s - loss: 0.4162 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 153/300
# 1/1 - 0s - loss: 0.4137 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 154/300
# 1/1 - 0s - loss: 0.4113 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 155/300
# 1/1 - 0s - loss: 0.4090 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 156/300
# 1/1 - 0s - loss: 0.4066 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 157/300
# 1/1 - 0s - loss: 0.4040 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 158/300
# 1/1 - 0s - loss: 0.4016 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 159/300
# 1/1 - 0s - loss: 0.3992 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 160/300
# 1/1 - 0s - loss: 0.3969 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 161/300
# 1/1 - 0s - loss: 0.3945 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 162/300
# 1/1 - 0s - loss: 0.3921 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 163/300
# 1/1 - 0s - loss: 0.3897 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 164/300
# 1/1 - 0s - loss: 0.3874 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 165/300
# 1/1 - 0s - loss: 0.3853 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 166/300
# 1/1 - 0s - loss: 0.3830 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 167/300
# 1/1 - 0s - loss: 0.3807 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 168/300
# 1/1 - 0s - loss: 0.3784 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 169/300
# 1/1 - 0s - loss: 0.3761 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 170/300
# 1/1 - 0s - loss: 0.3737 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 171/300
# 1/1 - 0s - loss: 0.3717 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 172/300
# 1/1 - 0s - loss: 0.3693 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 173/300
# 1/1 - 0s - loss: 0.3676 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 174/300
# 1/1 - 0s - loss: 0.3649 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 175/300
# 1/1 - 0s - loss: 0.3630 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 176/300
# 1/1 - 0s - loss: 0.3609 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 177/300
# 1/1 - 0s - loss: 0.3588 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 178/300
# 1/1 - 0s - loss: 0.3567 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 179/300
# 1/1 - 0s - loss: 0.3546 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 180/300
# 1/1 - 0s - loss: 0.3525 - binary_accuracy: 1.0000 - 7ms/epoch - 7ms/step
# Epoch 181/300
# 1/1 - 0s - loss: 0.3503 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 182/300
# 1/1 - 0s - loss: 0.3482 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 183/300
# 1/1 - 0s - loss: 0.3463 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 184/300
# 1/1 - 0s - loss: 0.3441 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 185/300
# 1/1 - 0s - loss: 0.3420 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 186/300
# 1/1 - 0s - loss: 0.3401 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 187/300
# 1/1 - 0s - loss: 0.3381 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 188/300
# 1/1 - 0s - loss: 0.3360 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 189/300
# 1/1 - 0s - loss: 0.3339 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 190/300
# 1/1 - 0s - loss: 0.3320 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 191/300
# 1/1 - 0s - loss: 0.3300 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 192/300
# 1/1 - 0s - loss: 0.3281 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 193/300
# 1/1 - 0s - loss: 0.3262 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 194/300
# 1/1 - 0s - loss: 0.3243 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 195/300
# 1/1 - 0s - loss: 0.3224 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 196/300
# 1/1 - 0s - loss: 0.3203 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 197/300
# 1/1 - 0s - loss: 0.3185 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 198/300
# 1/1 - 0s - loss: 0.3165 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 199/300
# 1/1 - 0s - loss: 0.3148 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 200/300
# 1/1 - 0s - loss: 0.3131 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 201/300
# 1/1 - 0s - loss: 0.3110 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 202/300
# 1/1 - 0s - loss: 0.3092 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 203/300
# 1/1 - 0s - loss: 0.3074 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 204/300
# 1/1 - 0s - loss: 0.3057 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 205/300
# 1/1 - 0s - loss: 0.3038 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 206/300
# 1/1 - 0s - loss: 0.3019 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 207/300
# 1/1 - 0s - loss: 0.3001 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 208/300
# 1/1 - 0s - loss: 0.2984 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 209/300
# 1/1 - 0s - loss: 0.2966 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 210/300
# 1/1 - 0s - loss: 0.2950 - binary_accuracy: 1.0000 - 997us/epoch - 997us/step
# Epoch 211/300
# 1/1 - 0s - loss: 0.2933 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 212/300
# 1/1 - 0s - loss: 0.2915 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 213/300
# 1/1 - 0s - loss: 0.2900 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 214/300
# 1/1 - 0s - loss: 0.2883 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 215/300
# 1/1 - 0s - loss: 0.2865 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 216/300
# 1/1 - 0s - loss: 0.2849 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 217/300
# 1/1 - 0s - loss: 0.2832 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 218/300
# 1/1 - 0s - loss: 0.2816 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 219/300
# 1/1 - 0s - loss: 0.2800 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 220/300
# 1/1 - 0s - loss: 0.2784 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 221/300
# 1/1 - 0s - loss: 0.2768 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 222/300
# 1/1 - 0s - loss: 0.2753 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 223/300
# 1/1 - 0s - loss: 0.2738 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 224/300
# 1/1 - 0s - loss: 0.2722 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 225/300
# 1/1 - 0s - loss: 0.2706 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 226/300
# 1/1 - 0s - loss: 0.2691 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 227/300
# 1/1 - 0s - loss: 0.2677 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 228/300
# 1/1 - 0s - loss: 0.2661 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 229/300
# 1/1 - 0s - loss: 0.2647 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 230/300
# 1/1 - 0s - loss: 0.2633 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 231/300
# 1/1 - 0s - loss: 0.2617 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 232/300
# 1/1 - 0s - loss: 0.2603 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 233/300
# 1/1 - 0s - loss: 0.2589 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 234/300
# 1/1 - 0s - loss: 0.2575 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 235/300
# 1/1 - 0s - loss: 0.2562 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 236/300
# 1/1 - 0s - loss: 0.2547 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 237/300
# 1/1 - 0s - loss: 0.2533 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 238/300
# 1/1 - 0s - loss: 0.2519 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 239/300
# 1/1 - 0s - loss: 0.2504 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 240/300
# 1/1 - 0s - loss: 0.2492 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 241/300
# 1/1 - 0s - loss: 0.2479 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 242/300
# 1/1 - 0s - loss: 0.2465 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 243/300
# 1/1 - 0s - loss: 0.2451 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 244/300
# 1/1 - 0s - loss: 0.2438 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 245/300
# 1/1 - 0s - loss: 0.2426 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 246/300
# 1/1 - 0s - loss: 0.2415 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 247/300
# 1/1 - 0s - loss: 0.2399 - binary_accuracy: 1.0000 - 5ms/epoch - 5ms/step
# Epoch 248/300
# 1/1 - 0s - loss: 0.2388 - binary_accuracy: 1.0000 - 10ms/epoch - 10ms/step
# Epoch 249/300
# 1/1 - 0s - loss: 0.2375 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 250/300
# 1/1 - 0s - loss: 0.2362 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 251/300
# 1/1 - 0s - loss: 0.2350 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 252/300
# 1/1 - 0s - loss: 0.2339 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 253/300
# 1/1 - 0s - loss: 0.2326 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 254/300
# 1/1 - 0s - loss: 0.2315 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 255/300
# 1/1 - 0s - loss: 0.2303 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 256/300
# 1/1 - 0s - loss: 0.2291 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 257/300
# 1/1 - 0s - loss: 0.2279 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 258/300
# 1/1 - 0s - loss: 0.2268 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 259/300
# 1/1 - 0s - loss: 0.2256 - binary_accuracy: 1.0000 - 6ms/epoch - 6ms/step
# Epoch 260/300
# 1/1 - 0s - loss: 0.2245 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 261/300
# 1/1 - 0s - loss: 0.2234 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 262/300
# 1/1 - 0s - loss: 0.2223 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 263/300
# 1/1 - 0s - loss: 0.2214 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 264/300
# 1/1 - 0s - loss: 0.2201 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 265/300
# 1/1 - 0s - loss: 0.2191 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 266/300
# 1/1 - 0s - loss: 0.2181 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 267/300
# 1/1 - 0s - loss: 0.2170 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 268/300
# 1/1 - 0s - loss: 0.2159 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 269/300
# 1/1 - 0s - loss: 0.2149 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 270/300
# 1/1 - 0s - loss: 0.2139 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 271/300
# 1/1 - 0s - loss: 0.2128 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 272/300
# 1/1 - 0s - loss: 0.2118 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 273/300
# 1/1 - 0s - loss: 0.2108 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 274/300
# 1/1 - 0s - loss: 0.2099 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 275/300
# 1/1 - 0s - loss: 0.2089 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 276/300
# 1/1 - 0s - loss: 0.2079 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 277/300
# 1/1 - 0s - loss: 0.2069 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 278/300
# 1/1 - 0s - loss: 0.2060 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 279/300
# 1/1 - 0s - loss: 0.2051 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 280/300
# 1/1 - 0s - loss: 0.2041 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 281/300
# 1/1 - 0s - loss: 0.2036 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 282/300
# 1/1 - 0s - loss: 0.2023 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 283/300
# 1/1 - 0s - loss: 0.2015 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 284/300
# 1/1 - 0s - loss: 0.2005 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 285/300
# 1/1 - 0s - loss: 0.1997 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 286/300
# 1/1 - 0s - loss: 0.1988 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 287/300
# 1/1 - 0s - loss: 0.1980 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 288/300
# 1/1 - 0s - loss: 0.1971 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 289/300
# 1/1 - 0s - loss: 0.1963 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 290/300
# 1/1 - 0s - loss: 0.1954 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 291/300
# 1/1 - 0s - loss: 0.1945 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 292/300
# 1/1 - 0s - loss: 0.1937 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 293/300
# 1/1 - 0s - loss: 0.1929 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 294/300
# 1/1 - 0s - loss: 0.1921 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 295/300
# 1/1 - 0s - loss: 0.1912 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 296/300
# 1/1 - 0s - loss: 0.1904 - binary_accuracy: 1.0000 - 3ms/epoch - 3ms/step
# Epoch 297/300
# 1/1 - 0s - loss: 0.1896 - binary_accuracy: 1.0000 - 4ms/epoch - 4ms/step
# Epoch 298/300
# 1/1 - 0s - loss: 0.1888 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 299/300
# 1/1 - 0s - loss: 0.1882 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step
# Epoch 300/300
# 1/1 - 0s - loss: 0.1875 - binary_accuracy: 1.0000 - 2ms/epoch - 2ms/step

# %%
# 5. 학습과정 살펴보기
hist.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy'])

# %%
fig, loss_ax = plt.subplots(figsize=(10,5))
loss_ax.plot(hist.history['loss'], 'b', label='loss')
acc_ax = loss_ax.twinx() # loss_ax와 x축을 공유하는 acc_ax
acc_ax.plot(hist.history['binary_accuracy'], 'r', label='binary_accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('binary_accuracy')
loss_ax.legend(loc='center right')
acc_ax.legend(loc='center left')
plt.show()

# %%
# 모델 평가하기
score = model.evaluate(x_data, y_data) # loss & metrics(binary accuracy)
print('loss :', score[0])
print('accuracy :', score[1])
# Out:
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1869 - binary_accuracy: 1.0000
# loss : 0.18686875700950623
# accuracy : 1.0

# %%
# 예측하기
model.predict(np.array([[0, 1]]))
# Out:
# 1/1 [==============================] - 0s 60ms/step
# array([[0.6047622]], dtype=float32)
